# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
# from api_keys import weather_api_key
from dotenv import load_dotenv
import os

load_dotenv()
weather_api_key = os.getenv("OPEN_WEATHERMAP_API_KEY")

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 600

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
#url = "http://api.openweathermap.org/data/2.5/weather?"
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#query_url = f"{url}appid={weather_api_key}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kone
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | puerto natales
# Processing Record 4 of Set 1 | santo antonio
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | brasilia de minas
# Processing Record 8 of Set 1 | laayoune
# Processing Record 9 of Set 1 | grytviken
# Processing Record 10 of Set 1 | ribeira grande
# Processing Record 11 of Set 1 | nahiyat ash shinafiyah
# Processing Record 12 of Set 1 | alton north (historical)
# Processing Record 13 of Set 1 | blackmans bay
# Processing Record 14 of Set 1 | qaqortoq
# Processing Record 15 of Set 1 | waitangi
# Processing Record 16 of Set 1 | oranjemund
# Processing Record 17 of Set 1 | wailua homesteads
# Processing Record 18 of Set 1 | port-aux-francais
# Processing Record 19 of Set 1 | enewetak
# Processing Record 20 of Set 1 | stanley
# Processing Record 21 of Set 1 | lompoc
# Processing Record 22 of Set 1 | anadyr
# Processing Record 23 of Set 1 | college
# Processing Record 24 of Set 1 | la passe
# Processing Record 25 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 26 of Set 1 | vorgashor
# Processing Record 27 of Set 1 | papatowai
# Processing Record 28 of Set 1 | west island
# Processing Record 29 of Set 1 | sassandra
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | edinburgh of the seven seas
# Processing Record 32 of Set 1 | angaur state
# Processing Record 33 of Set 1 | revelstoke
# Processing Record 34 of Set 1 | tiksi
# Processing Record 35 of Set 1 | gueltat zemmour
# City not found. Skipping...
# Processing Record 36 of Set 1 | thompson
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | sarmiento
# Processing Record 39 of Set 1 | adamstown
# Processing Record 40 of Set 1 | yuzhno-kurilsk
# Processing Record 41 of Set 1 | hawaiian paradise park
# Processing Record 42 of Set 1 | iqaluit
# Processing Record 43 of Set 1 | segezha
# Processing Record 44 of Set 1 | leava
# Processing Record 45 of Set 1 | yaren
# Processing Record 46 of Set 1 | fergus falls
# Processing Record 47 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 50 of Set 1 | alice springs
# Processing Record 0 of Set 2 | mount gambier
# Processing Record 1 of Set 2 | puerto aysen
# Processing Record 2 of Set 2 | iskateley
# Processing Record 3 of Set 2 | longboat key
# Processing Record 4 of Set 2 | port mathurin
# Processing Record 5 of Set 2 | el zulia
# Processing Record 6 of Set 2 | bethel
# Processing Record 7 of Set 2 | revda
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | gizo
# Processing Record 10 of Set 2 | ndende
# Processing Record 11 of Set 2 | kiunga
# Processing Record 12 of Set 2 | loukhi
# Processing Record 13 of Set 2 | hubynykha
# Processing Record 14 of Set 2 | atafu village
# Processing Record 15 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 16 of Set 2 | bilibino
# Processing Record 17 of Set 2 | kingston
# Processing Record 18 of Set 2 | shizunai-furukawacho
# Processing Record 19 of Set 2 | bodaybo
# Processing Record 20 of Set 2 | punta arenas
# Processing Record 21 of Set 2 | mana
# Processing Record 22 of Set 2 | badger
# Processing Record 23 of Set 2 | flying fish cove
# Processing Record 24 of Set 2 | veraval
# Processing Record 25 of Set 2 | lihue
# Processing Record 26 of Set 2 | sarikei
# Processing Record 27 of Set 2 | saipan
# Processing Record 28 of Set 2 | pitimbu
# Processing Record 29 of Set 2 | ejura
# Processing Record 30 of Set 2 | rio gallegos
# Processing Record 31 of Set 2 | georgetown
# Processing Record 32 of Set 2 | nichinan
# Processing Record 33 of Set 2 | al-hamdaniya
# Processing Record 34 of Set 2 | udachny
# Processing Record 35 of Set 2 | broome
# Processing Record 36 of Set 2 | zyryanskoye
# Processing Record 37 of Set 2 | dado
# Processing Record 38 of Set 2 | codrington
# Processing Record 39 of Set 2 | labuan
# Processing Record 40 of Set 2 | olonkinbyen
# Processing Record 41 of Set 2 | olyokminsk
# Processing Record 42 of Set 2 | baotou
# Processing Record 43 of Set 2 | fort st. john
# Processing Record 44 of Set 2 | verkhnevilyuysk
# Processing Record 45 of Set 2 | ketchikan
# Processing Record 46 of Set 2 | selfoss
# Processing Record 47 of Set 2 | vila velha
# Processing Record 48 of Set 2 | whitehorse
# Processing Record 49 of Set 2 | sangsong-ni
# Processing Record 0 of Set 3 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 1 of Set 3 | avarua
# Processing Record 2 of Set 3 | margaret river
# Processing Record 3 of Set 3 | chudovo
# Processing Record 4 of Set 3 | goundam
# Processing Record 5 of Set 3 | san julian
# Processing Record 6 of Set 3 | aykhal
# Processing Record 7 of Set 3 | n'zeto
# Processing Record 8 of Set 3 | las heras
# Processing Record 9 of Set 3 | coahuayana de hidalgo
# Processing Record 10 of Set 3 | mermoz boabab
# Processing Record 11 of Set 3 | pama
# Processing Record 12 of Set 3 | naze
# Processing Record 13 of Set 3 | isangel
# Processing Record 14 of Set 3 | broken hill
# Processing Record 15 of Set 3 | tangalle
# Processing Record 16 of Set 3 | severo-yeniseyskiy
# Processing Record 17 of Set 3 | mejit
# Processing Record 18 of Set 3 | ouddorp
# Processing Record 19 of Set 3 | mo i rana
# Processing Record 20 of Set 3 | brookings
# Processing Record 21 of Set 3 | am timan
# Processing Record 22 of Set 3 | baki
# Processing Record 23 of Set 3 | nar'yan-mar
# Processing Record 24 of Set 3 | ad darb
# Processing Record 25 of Set 3 | tralee
# Processing Record 26 of Set 3 | haiku-pauwela
# Processing Record 27 of Set 3 | revadanda
# Processing Record 28 of Set 3 | zhezqazghan
# Processing Record 29 of Set 3 | kenai
# Processing Record 30 of Set 3 | pokhara
# Processing Record 31 of Set 3 | horta
# Processing Record 32 of Set 3 | mar del plata
# Processing Record 33 of Set 3 | juan de ayolas
# Processing Record 34 of Set 3 | east london
# Processing Record 35 of Set 3 | kill devil hills
# Processing Record 36 of Set 3 | miguel ahumada
# Processing Record 37 of Set 3 | buka
# Processing Record 38 of Set 3 | fuerte olimpo
# Processing Record 39 of Set 3 | port hueneme
# Processing Record 40 of Set 3 | nagornyy
# Processing Record 41 of Set 3 | rancho palos verdes
# Processing Record 42 of Set 3 | koton-karfe
# Processing Record 43 of Set 3 | howrah
# Processing Record 44 of Set 3 | labytnangi
# Processing Record 45 of Set 3 | fort mcmurray
# Processing Record 46 of Set 3 | wanning
# Processing Record 47 of Set 3 | pisco
# Processing Record 48 of Set 3 | remire-montjoly
# Processing Record 49 of Set 3 | invercargill
# Processing Record 0 of Set 4 | durham
# Processing Record 1 of Set 4 | tazovsky
# Processing Record 2 of Set 4 | sarria
# Processing Record 3 of Set 4 | niort
# Processing Record 4 of Set 4 | arkhangel'sk
# Processing Record 5 of Set 4 | alofi
# Processing Record 6 of Set 4 | the pas
# Processing Record 7 of Set 4 | el granada
# Processing Record 8 of Set 4 | onguday
# Processing Record 9 of Set 4 | saldanha
# Processing Record 10 of Set 4 | youghal
# Processing Record 11 of Set 4 | chipinge
# Processing Record 12 of Set 4 | kerikeri
# Processing Record 13 of Set 4 | talnakh
# Processing Record 14 of Set 4 | kununurra
# Processing Record 15 of Set 4 | seria
# Processing Record 16 of Set 4 | marrakesh
# Processing Record 17 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 18 of Set 4 | kitimat
# Processing Record 19 of Set 4 | tofol
# Processing Record 20 of Set 4 | ancud
# Processing Record 21 of Set 4 | conduaga
# Processing Record 22 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 23 of Set 4 | am djarass
# City not found. Skipping...
# Processing Record 24 of Set 4 | komsomolets
# Processing Record 25 of Set 4 | kalabo
# Processing Record 26 of Set 4 | monterey
# Processing Record 27 of Set 4 | taitung city
# Processing Record 28 of Set 4 | newman
# Processing Record 29 of Set 4 | magong
# Processing Record 30 of Set 4 | dogonbadan
# Processing Record 31 of Set 4 | kourou
# Processing Record 32 of Set 4 | safi
# Processing Record 33 of Set 4 | mata-utu
# Processing Record 34 of Set 4 | nyurba
# Processing Record 35 of Set 4 | queenstown
# Processing Record 36 of Set 4 | port elizabeth
# Processing Record 37 of Set 4 | nadym
# Processing Record 38 of Set 4 | bamboo flat
# Processing Record 39 of Set 4 | ramhormoz
# Processing Record 40 of Set 4 | olinda
# Processing Record 41 of Set 4 | ii
# City not found. Skipping...
# Processing Record 42 of Set 4 | los chavez
# Processing Record 43 of Set 4 | nova sintra
# Processing Record 44 of Set 4 | urengoy
# Processing Record 45 of Set 4 | uturoa
# Processing Record 46 of Set 4 | little cayman
# City not found. Skipping...
# Processing Record 47 of Set 4 | cold lake
# Processing Record 48 of Set 4 | hadibu
# Processing Record 49 of Set 4 | richards bay
# Processing Record 0 of Set 5 | khandyga
# Processing Record 1 of Set 5 | yanykurgan
# Processing Record 2 of Set 5 | lerwick
# Processing Record 3 of Set 5 | ugoofaaru
# Processing Record 4 of Set 5 | utrik
# Processing Record 5 of Set 5 | akhuryan
# Processing Record 6 of Set 5 | kodiak
# Processing Record 7 of Set 5 | kimbe
# Processing Record 8 of Set 5 | colares
# Processing Record 9 of Set 5 | qamdo
# Processing Record 10 of Set 5 | norderney
# Processing Record 11 of Set 5 | temiskaming shores
# Processing Record 12 of Set 5 | mossel bay
# Processing Record 13 of Set 5 | isafjordur
# Processing Record 14 of Set 5 | midyat
# Processing Record 15 of Set 5 | quatre cocos
# Processing Record 16 of Set 5 | timbuktu
# Processing Record 17 of Set 5 | kertih
# Processing Record 18 of Set 5 | bull savanna
# Processing Record 19 of Set 5 | mahina
# Processing Record 20 of Set 5 | chontaul
# Processing Record 21 of Set 5 | vinh
# Processing Record 22 of Set 5 | grand falls-windsor
# Processing Record 23 of Set 5 | luderitz
# Processing Record 24 of Set 5 | itoman
# Processing Record 25 of Set 5 | gimcheon
# Processing Record 26 of Set 5 | warman
# Processing Record 27 of Set 5 | cairns city
# City not found. Skipping...
# Processing Record 28 of Set 5 | sopela
# Processing Record 29 of Set 5 | port saint john's
# Processing Record 30 of Set 5 | ilulissat
# Processing Record 31 of Set 5 | kapuskasing
# Processing Record 32 of Set 5 | port isabel
# Processing Record 33 of Set 5 | nouadhibou
# Processing Record 34 of Set 5 | sandakan
# Processing Record 35 of Set 5 | embi
# Processing Record 36 of Set 5 | saudarkrokur
# Processing Record 37 of Set 5 | vila franca do campo
# Processing Record 38 of Set 5 | praia da vitoria
# Processing Record 39 of Set 5 | arkhipo-osipovka
# Processing Record 40 of Set 5 | karratha
# Processing Record 41 of Set 5 | christchurch
# Processing Record 42 of Set 5 | cabo san lucas
# Processing Record 43 of Set 5 | cambria
# Processing Record 44 of Set 5 | sabang
# Processing Record 45 of Set 5 | st. john's
# Processing Record 46 of Set 5 | basco
# Processing Record 47 of Set 5 | tursunzoda
# Processing Record 48 of Set 5 | soto la marina
# Processing Record 49 of Set 5 | gonabad
# Processing Record 0 of Set 6 | kotabumi
# Processing Record 1 of Set 6 | kailua-kona
# Processing Record 2 of Set 6 | yamada
# Processing Record 3 of Set 6 | gadzhiyevo
# Processing Record 4 of Set 6 | lazaro cardenas
# Processing Record 5 of Set 6 | longyearbyen
# Processing Record 6 of Set 6 | enniscorthy
# Processing Record 7 of Set 6 | angol
# Processing Record 8 of Set 6 | libertad
# Processing Record 9 of Set 6 | dazuocun
# Processing Record 10 of Set 6 | esquel
# Processing Record 11 of Set 6 | fabens
# Processing Record 12 of Set 6 | grand-lahou
# Processing Record 13 of Set 6 | gisborne
# Processing Record 14 of Set 6 | betio village
# Processing Record 15 of Set 6 | lodja
# Processing Record 16 of Set 6 | jamestown
# Processing Record 17 of Set 6 | kapa'a
# Processing Record 18 of Set 6 | melekeok village
# Processing Record 19 of Set 6 | serdar
# Processing Record 20 of Set 6 | awjilah
# Processing Record 21 of Set 6 | tura
# Processing Record 22 of Set 6 | northam
# Processing Record 23 of Set 6 | ivrea
# Processing Record 24 of Set 6 | puerto madryn
# Processing Record 25 of Set 6 | taoudenni
# Processing Record 26 of Set 6 | mount pearl
# Processing Record 27 of Set 6 | susuman
# Processing Record 28 of Set 6 | dar kulayb
# Processing Record 29 of Set 6 | sitka
# Processing Record 30 of Set 6 | geraldton
# Processing Record 31 of Set 6 | muroto-misakicho
# Processing Record 32 of Set 6 | buulobarde
# Processing Record 33 of Set 6 | happy valley-goose bay
# Processing Record 34 of Set 6 | kotel'nikovo
# Processing Record 35 of Set 6 | paragominas
# Processing Record 36 of Set 6 | hamilton
# Processing Record 37 of Set 6 | whangarei
# Processing Record 38 of Set 6 | prince rupert
# Processing Record 39 of Set 6 | aasiaat
# Processing Record 40 of Set 6 | necochea
# Processing Record 41 of Set 6 | mistrato
# Processing Record 42 of Set 6 | hellin
# Processing Record 43 of Set 6 | dar naim
# City not found. Skipping...
# Processing Record 44 of Set 6 | konarka
# Processing Record 45 of Set 6 | namibe
# Processing Record 46 of Set 6 | dwarka
# Processing Record 47 of Set 6 | nabire
# Processing Record 48 of Set 6 | vertientes
# Processing Record 49 of Set 6 | balkashino
# Processing Record 0 of Set 7 | espargos
# City not found. Skipping...
# Processing Record 1 of Set 7 | lazarevskoye
# Processing Record 2 of Set 7 | okha
# Processing Record 3 of Set 7 | inonu
# Processing Record 4 of Set 7 | pueblo nuevo
# Processing Record 5 of Set 7 | salcininkai
# Processing Record 6 of Set 7 | dickinson
# Processing Record 7 of Set 7 | parras de la fuente
# Processing Record 8 of Set 7 | baruun-urt
# Processing Record 9 of Set 7 | mugia
# Processing Record 10 of Set 7 | hilo
# Processing Record 11 of Set 7 | madaba
# Processing Record 12 of Set 7 | villa unida
# City not found. Skipping...
# Processing Record 13 of Set 7 | masina
# Processing Record 14 of Set 7 | andapa
# Processing Record 15 of Set 7 | brezina
# Processing Record 16 of Set 7 | coquimbo
# Processing Record 17 of Set 7 | kirakira
# Processing Record 18 of Set 7 | goz beida
# Processing Record 19 of Set 7 | arraial do cabo
# Processing Record 20 of Set 7 | santa isabel
# Processing Record 21 of Set 7 | flin flon
# Processing Record 22 of Set 7 | mirabad
# Processing Record 23 of Set 7 | nguigmi
# Processing Record 24 of Set 7 | walvis bay
# Processing Record 25 of Set 7 | sinjai
# Processing Record 26 of Set 7 | saint-denis
# Processing Record 27 of Set 7 | wabag
# Processing Record 28 of Set 7 | nemuro
# Processing Record 29 of Set 7 | kataba
# Processing Record 30 of Set 7 | kingaroy
# Processing Record 31 of Set 7 | keflavik
# Processing Record 32 of Set 7 | tarawa
# Processing Record 33 of Set 7 | tsiombe
# Processing Record 34 of Set 7 | port alfred
# Processing Record 35 of Set 7 | salinas
# Processing Record 36 of Set 7 | constantia
# Processing Record 37 of Set 7 | mount isa
# Processing Record 38 of Set 7 | inhambane
# Processing Record 39 of Set 7 | sale
# Processing Record 40 of Set 7 | dosso
# Processing Record 41 of Set 7 | bardstown
# Processing Record 42 of Set 7 | henderson
# Processing Record 43 of Set 7 | vilyuchinsk
# Processing Record 44 of Set 7 | ust-nera
# Processing Record 45 of Set 7 | khanty-mansiysk
# Processing Record 46 of Set 7 | harstad
# Processing Record 47 of Set 7 | coroata
# Processing Record 48 of Set 7 | meadow lake
# Processing Record 49 of Set 7 | miri
# Processing Record 0 of Set 8 | pacific grove
# Processing Record 1 of Set 8 | rakops
# Processing Record 2 of Set 8 | la'ie
# Processing Record 3 of Set 8 | savave village
# City not found. Skipping...
# Processing Record 4 of Set 8 | chonchi
# Processing Record 5 of Set 8 | san andros
# City not found. Skipping...
# Processing Record 6 of Set 8 | dudinka
# Processing Record 7 of Set 8 | klaksvik
# Processing Record 8 of Set 8 | puerto lleras
# Processing Record 9 of Set 8 | amga
# Processing Record 10 of Set 8 | thinadhoo
# Processing Record 11 of Set 8 | ekibastuz
# Processing Record 12 of Set 8 | kavaratti
# Processing Record 13 of Set 8 | cabedelo
# Processing Record 14 of Set 8 | nova vicosa
# Processing Record 15 of Set 8 | umm kaddadah
# Processing Record 16 of Set 8 | xinyuan
# Processing Record 17 of Set 8 | la punta
# Processing Record 18 of Set 8 | vilyuysk
# Processing Record 19 of Set 8 | sao felix do xingu
# Processing Record 20 of Set 8 | paulden
# Processing Record 21 of Set 8 | polyarnyy
# Processing Record 22 of Set 8 | kasongo
# Processing Record 23 of Set 8 | maragogi
# Processing Record 24 of Set 8 | bejaia
# Processing Record 25 of Set 8 | valparaiso
# Processing Record 26 of Set 8 | hasaki
# Processing Record 27 of Set 8 | crozon
# Processing Record 28 of Set 8 | beacon square
# Processing Record 29 of Set 8 | paciran
# Processing Record 30 of Set 8 | mount carmel
# Processing Record 31 of Set 8 | guerrero negro
# Processing Record 32 of Set 8 | kuqa
# Processing Record 33 of Set 8 | gannan
# Processing Record 34 of Set 8 | alo
# Processing Record 35 of Set 8 | dakhla
# Processing Record 36 of Set 8 | touros
# Processing Record 37 of Set 8 | rawa mazowiecka
# Processing Record 38 of Set 8 | lamu
# Processing Record 39 of Set 8 | pangai
# Processing Record 40 of Set 8 | itapemirim
# Processing Record 41 of Set 8 | auki
# Processing Record 42 of Set 8 | gambela
# Processing Record 43 of Set 8 | forster
# Processing Record 44 of Set 8 | san clemente del tuyu
# Processing Record 45 of Set 8 | ormara
# Processing Record 46 of Set 8 | osorno
# Processing Record 47 of Set 8 | beitbridge
# Processing Record 48 of Set 8 | weno
# Processing Record 49 of Set 8 | shahrak
# Processing Record 0 of Set 9 | kamaishi
# Processing Record 1 of Set 9 | freetown
# Processing Record 2 of Set 9 | kasulu
# Processing Record 3 of Set 9 | san patricio
# Processing Record 4 of Set 9 | bel ombre
# Processing Record 5 of Set 9 | george town
# Processing Record 6 of Set 9 | tolanaro
# Processing Record 7 of Set 9 | talagang
# Processing Record 8 of Set 9 | fale old settlement
# Processing Record 9 of Set 9 | cidreira
# Processing Record 10 of Set 9 | hammerfest
# Processing Record 11 of Set 9 | mikhaylovka
# Processing Record 12 of Set 9 | doctor mora
# Processing Record 13 of Set 9 | bonthe
# Processing Record 14 of Set 9 | chivhu
# Processing Record 15 of Set 9 | gonzales
# Processing Record 16 of Set 9 | la ronge
# Processing Record 17 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 18 of Set 9 | kyren
# Processing Record 19 of Set 9 | tuy hoa
# Processing Record 20 of Set 9 | tarumovka
# Processing Record 21 of Set 9 | mwanza
# Processing Record 22 of Set 9 | derbent
# Processing Record 23 of Set 9 | crane
# Processing Record 24 of Set 9 | vernon
# Processing Record 25 of Set 9 | pierre
# Processing Record 26 of Set 9 | karamay
# Processing Record 27 of Set 9 | salalah
# Processing Record 28 of Set 9 | taltal
# Processing Record 29 of Set 9 | khovd
# Processing Record 30 of Set 9 | elko
# Processing Record 31 of Set 9 | balangiga
# Processing Record 32 of Set 9 | shihezi
# Processing Record 33 of Set 9 | preobrazheniye
# Processing Record 34 of Set 9 | tarko-sale
# Processing Record 35 of Set 9 | midvagur
# Processing Record 36 of Set 9 | carnarvon
# Processing Record 37 of Set 9 | sangueya
# Processing Record 38 of Set 9 | pirallahi
# Processing Record 39 of Set 9 | kokopo
# Processing Record 40 of Set 9 | trairi
# Processing Record 41 of Set 9 | limoux
# Processing Record 42 of Set 9 | nikel
# Processing Record 43 of Set 9 | puerto san jose
# Processing Record 44 of Set 9 | fort bragg
# Processing Record 45 of Set 9 | comodoro rivadavia
# Processing Record 46 of Set 9 | caiaponia
# Processing Record 47 of Set 9 | manokwari
# Processing Record 48 of Set 9 | kayangel
# Processing Record 49 of Set 9 | nuku'alofa
# Processing Record 0 of Set 10 | altai
# Processing Record 1 of Set 10 | kayenta
# Processing Record 2 of Set 10 | chicxulub puerto
# City not found. Skipping...
# Processing Record 3 of Set 10 | afaahiti
# Processing Record 4 of Set 10 | peace river
# Processing Record 5 of Set 10 | san jose del guaviare
# Processing Record 6 of Set 10 | guarapari
# Processing Record 7 of Set 10 | lebu
# Processing Record 8 of Set 10 | orlov
# Processing Record 9 of Set 10 | pavlodar
# Processing Record 10 of Set 10 | lubango
# Processing Record 11 of Set 10 | kristiansund
# Processing Record 12 of Set 10 | princeville
# Processing Record 13 of Set 10 | nyala
# Processing Record 14 of Set 10 | tanout
# Processing Record 15 of Set 10 | feltre
# Processing Record 16 of Set 10 | placido de castro
# Processing Record 17 of Set 10 | el arahal
# Processing Record 18 of Set 10 | monrovia
# Processing Record 19 of Set 10 | acajutla
# Processing Record 20 of Set 10 | mili
# Processing Record 21 of Set 10 | saint-francois
# Processing Record 22 of Set 10 | demyansk
# Processing Record 23 of Set 10 | whakatane
# Processing Record 24 of Set 10 | kaa-khem
# Processing Record 25 of Set 10 | ariquemes
# Processing Record 26 of Set 10 | fonadhoo
# City not found. Skipping...
# Processing Record 27 of Set 10 | quellon
# Processing Record 28 of Set 10 | sagarejo
# Processing Record 29 of Set 10 | toba tek singh
# Processing Record 30 of Set 10 | baicheng
# Processing Record 31 of Set 10 | chernomorskoye
# Processing Record 32 of Set 10 | maceio
# Processing Record 33 of Set 10 | vadso
# Processing Record 34 of Set 10 | pangody
# Processing Record 35 of Set 10 | aleg
# Processing Record 36 of Set 10 | xinqing
# Processing Record 37 of Set 10 | teluk nibung
# Processing Record 38 of Set 10 | tchintabaraden
# Processing Record 39 of Set 10 | kudahuvadhoo
# Processing Record 40 of Set 10 | chaohu
# Processing Record 41 of Set 10 | arar
# Processing Record 42 of Set 10 | rockland
# Processing Record 43 of Set 10 | masterton
# Processing Record 44 of Set 10 | la gi
# Processing Record 45 of Set 10 | xinmin
# Processing Record 46 of Set 10 | caconda
# Processing Record 47 of Set 10 | meybod
# Processing Record 48 of Set 10 | kwali
# Processing Record 49 of Set 10 | belokurikha
# Processing Record 0 of Set 11 | birni n konni
# Processing Record 1 of Set 11 | choyr
# Processing Record 2 of Set 11 | aripuana
# Processing Record 3 of Set 11 | vieste
# Processing Record 4 of Set 11 | tripoli
# Processing Record 5 of Set 11 | ubari
# Processing Record 6 of Set 11 | talara
# Processing Record 7 of Set 11 | salinopolis
# Processing Record 8 of Set 11 | moroni
# Processing Record 9 of Set 11 | mathba
# Processing Record 10 of Set 11 | cinco saltos
# Processing Record 11 of Set 11 | kandahar
# Processing Record 12 of Set 11 | doctor arroyo
# Processing Record 13 of Set 11 | bingerville
# Processing Record 14 of Set 11 | laguna
# Processing Record 15 of Set 11 | praia
# Processing Record 16 of Set 11 | san antonio de pale
# Processing Record 17 of Set 11 | orcopampa
# Processing Record 18 of Set 11 | sternberk
# Processing Record 19 of Set 11 | esmeraldas
# Processing Record 20 of Set 11 | tionk essil
# Processing Record 21 of Set 11 | gstaad
# Processing Record 22 of Set 11 | daudnagar
# Processing Record 23 of Set 11 | idri
# Processing Record 24 of Set 11 | mariental
# Processing Record 25 of Set 11 | boone
# Processing Record 26 of Set 11 | okhotsk
# Processing Record 27 of Set 11 | villa gesell
# Processing Record 28 of Set 11 | zaysan
# Processing Record 29 of Set 11 | lensk
# Processing Record 30 of Set 11 | amarante do maranhao
# Processing Record 31 of Set 11 | murud
# Processing Record 32 of Set 11 | san angelo
# Processing Record 33 of Set 11 | vakfikebir
# Processing Record 34 of Set 11 | kharkhorin
# Processing Record 35 of Set 11 | chistopol'
# Processing Record 36 of Set 11 | ipora
# Processing Record 37 of Set 11 | colchani
# Processing Record 38 of Set 11 | lisakovsk
# Processing Record 39 of Set 11 | morehead city
# Processing Record 40 of Set 11 | santa ines
# Processing Record 41 of Set 11 | paragould
# Processing Record 42 of Set 11 | labrador city
# Processing Record 43 of Set 11 | medicine hat
# Processing Record 44 of Set 11 | hirara
# Processing Record 45 of Set 11 | grabouw
# Processing Record 46 of Set 11 | karera
# Processing Record 47 of Set 11 | metlili chaamba
# Processing Record 48 of Set 11 | rongelap
# Processing Record 49 of Set 11 | tobol'sk
# Processing Record 0 of Set 12 | eraan
# Processing Record 1 of Set 12 | coro
# Processing Record 2 of Set 12 | micheweni
# Processing Record 3 of Set 12 | mizan teferi
# Processing Record 4 of Set 12 | brokopondo
# Processing Record 5 of Set 12 | ulsteinvik
# Processing Record 6 of Set 12 | lorinci
# Processing Record 7 of Set 12 | bardai
# Processing Record 8 of Set 12 | neon karlovasion
# Processing Record 9 of Set 12 | vingt cinq
# City not found. Skipping...
# Processing Record 10 of Set 12 | areka
# Processing Record 11 of Set 12 | barcelos
# Processing Record 12 of Set 12 | chul'man
# Processing Record 13 of Set 12 | quimili
# Processing Record 14 of Set 12 | abatskoye
# Processing Record 15 of Set 12 | kodinsk
# Processing Record 16 of Set 12 | porto novo
# Processing Record 17 of Set 12 | birao
# Processing Record 18 of Set 12 | nadi
# Processing Record 19 of Set 12 | zahedan
# Processing Record 20 of Set 12 | viedma
# Processing Record 21 of Set 12 | tefenni
# Processing Record 22 of Set 12 | ghadamis
# Processing Record 23 of Set 12 | garbahaarrey
# Processing Record 24 of Set 12 | pendra
# Processing Record 25 of Set 12 | bambous
# Processing Record 26 of Set 12 | lefkada
# Processing Record 27 of Set 12 | oriximina
# Processing Record 28 of Set 12 | iquitos
# Processing Record 29 of Set 12 | vikhorevka
# Processing Record 30 of Set 12 | sault ste. marie
# Processing Record 31 of Set 12 | caleta de carquin
# Processing Record 32 of Set 12 | palikir - national government center
# Processing Record 33 of Set 12 | aigues-mortes
# Processing Record 34 of Set 12 | alotau
# Processing Record 35 of Set 12 | holualoa
# Processing Record 36 of Set 12 | arawa
# Processing Record 37 of Set 12 | progreso
# Processing Record 38 of Set 12 | amalapuram
# Processing Record 39 of Set 12 | ijuw
# City not found. Skipping...
# Processing Record 40 of Set 12 | tanjung selor
# Processing Record 41 of Set 12 | antsohihy
# Processing Record 42 of Set 12 | sandnessjoen
# Processing Record 43 of Set 12 | ain sefra
# Processing Record 44 of Set 12 | sao joao da barra
# Processing Record 45 of Set 12 | yanbu
# Processing Record 46 of Set 12 | buckhannon
# Processing Record 47 of Set 12 | enriquillo
# Processing Record 48 of Set 12 | ocampo
# Processing Record 49 of Set 12 | pleiku
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            kone -21.0595  164.8658     67.48        87         100
# 1      bredasdorp -34.5322   20.0403     57.20        72         100
# 2  puerto natales -51.7236  -72.4875     32.45        86           0
# 3   santo antonio  -6.3106  -35.4789     87.22        49         100
# 4     yellowknife  62.4560 -114.3525     61.32        94          75
#
#    Wind Speed Country        Date
# 0        4.83      NC  1723383626
# 1       19.53      ZA  1723383627
# 2        2.30      CL  1723383511
# 3       12.03      BR  1723383630
# 4        8.05      CA  1723383631

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  kone -21.0595  164.8658     67.48        87         100
# 1            bredasdorp -34.5322   20.0403     57.20        72         100
# 2        puerto natales -51.7236  -72.4875     32.45        86           0
# 3         santo antonio  -6.3106  -35.4789     87.22        49         100
# 4           yellowknife  62.4560 -114.3525     61.32        94          75
#
#          Wind Speed Country        Date
# City_ID
# 0              4.83      NC  1723383626
# 1             19.53      ZA  1723383627
# 2              2.30      CL  1723383511
# 3             12.03      BR  1723383630
# 4              8.05      CA  1723383631

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
linear_regress = lambda x, y, title, text_coordinates: plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    linear_regress(x_values, y_values, title, text_coordinates)
    plt.xlabel("Latitude")
    plt.ylabel(title)
    plt.title(title)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 4                     yellowknife  62.4560 -114.3525     61.32        94
# 7                        laayoune  27.1622  -13.2032     89.94        43
# 9                  ribeira grande  38.5167  -28.7000     77.77        57
# 10         nahiyat ash shinafiyah  31.5874   44.6602    113.04        10
# 11       alton north (historical)  26.2953  -98.3045     83.95        86
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 4                75        8.05      CA  1723383631
# 7                 6       26.46      EH  1723383549
# 9                40       15.99      PT  1723383637
# 10                0       14.00      IQ  1723383638
# 11                0        1.01      US  1723383640

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  kone -21.0595  164.8658     67.48        87         100
# 1            bredasdorp -34.5322   20.0403     57.20        72         100
# 2        puerto natales -51.7236  -72.4875     32.45        86           0
# 3         santo antonio  -6.3106  -35.4789     87.22        49         100
# 5             hithadhoo  -0.6000   73.0833     82.69        75          64
#
#          Wind Speed Country        Date
# City_ID
# 0              4.83      NC  1723383626
# 1             19.53      ZA  1723383627
# 2              2.30      CL  1723383511
# 3             12.03      BR  1723383630
# 5             13.69      MV  1723383632

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
linear_equation = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(linear_equation, (10, 40), fontsize=15, color="red")
plt.title("Northern Hemisphere - Latitude vs. Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.3434282163299713

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
linear_equation = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(linear_equation, (-30, 50), fontsize=15, color="red")
plt.title("Southern Hemisphere - Latitude vs. Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7484742612026463

# %% [markdown]
# **Discussion about the linear relationship:** The temperature increases as we approach the equator (Latitude 0) and decreases as we move away from the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
linear_equation = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(linear_equation, (40, 10), fontsize=15, color="red")
plt.title("Northern Hemisphere - Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00045806075274996933

# %%
# Southern Hemisphere
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
linear_equation = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(linear_equation, (-30, 40), fontsize=15, color="red")
plt.title("Southern Hemisphere - Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.05424723305405183

# %% [markdown]
# **Discussion about the linear relationship:**
# The humidity is higher near the equator and decreases as we move away from the equator.
# The data shows that the humidity is higher near the equator and lower as we move away from the equator.
# The data shows that the humidity is higher in the Southern Hemisphere than in the Northern Hemisphere.
# The r-squared values show that the linear regression models are a good fit for the data.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
linear_equation = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(linear_equation, (40, 10), fontsize=15, color="red")
plt.title("Northern Hemisphere - Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.004856406223089917

# %%
# Southern Hemisphere
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
linear_equation = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(linear_equation, (-30, 40), fontsize=15, color="red")
plt.title("Southern Hemisphere - Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0044838707509215715

# %% [markdown]
# **Discussion about the linear relationship:**
# The cloudiness is higher near the equator and decreases as we move away from the equator.
# The data shows that the cloudiness is higher near the equator and lower as we move away from the equator.
# The data shows that the cloudiness is higher in the Southern Hemisphere than in the Northern Hemisphere.
# The r-squared values show that the linear regression models are a good fit for the data.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
linear_equation = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(linear_equation, (40, 25), fontsize=15, color="red")
plt.title("Northern Hemisphere - Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0020402461273206817

# %%
# Southern Hemisphere
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
linear_equation = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(linear_equation, (-30, 20), fontsize=15, color="red")
plt.title("Southern Hemisphere - Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.01730949691697572

# %% [markdown]
# **Discussion about the linear relationship:**
# The wind speed is higher near the equator and decreases as we move away from the equator.
# The data shows that the wind speed is higher near the equator and lower as we move away from the equator.
# The data shows that the wind speed is higher in the Southern Hemisphere than in the Northern Hemisphere.
# The r-squared values show that the linear regression models are a good fit for the data.
